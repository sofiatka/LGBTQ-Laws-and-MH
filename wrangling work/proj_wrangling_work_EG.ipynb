# %%
import pandas as pd 
#import os as os

# %%
#os.getcwd()

# %%
df=pd.read_csv('https://www.aclu.org/wp-json/api/legislation/csv/74348')

# %%
df = df.iloc[0:-1]

# %%
df=df.drop(columns = 'In Court Link')

# %%
df['State'].value_counts()
# Out:
# State
# Oklahoma          54
# Iowa              34
# Missouri          31
# Tennessee         31
# South Carolina    28
# West Virginia     25
# New Hampshire     17
# Mississippi       15
# Kansas            15
# Wisconsin         14
# Virginia          11
# Arizona           11
# Florida           11
# Minnesota         11
# Utah              10
# Wyoming           10
# Kentucky          10
# Michigan           9
# Georgia            9
# Hawaii             9
# New Jersey         7
# Ohio               7
# North Carolina     6
# Idaho              6
# Indiana            5
# Alaska             5
# Illinois           5
# Washington         4
# Nebraska           4
# Alabama            3
# Pennsylvania       3
# New Mexico         2
# Oregon             2
# Maryland           2
# Rhode Island       2
# Puerto Rico        2
# Vermont            2
# Massachusetts      2
# Maine              2
# South Dakota       1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            State Bill Name                  Issues     Status Status Detail  \
# count        437       437                     437        423           407
# unique        40       436                      93          4            78
# top     Oklahoma  H.B.1205  Other anti-LGBTQ bills  Advancing  Carried over
# freq          54         2                      49        235           150
#
#        Status Date
# count          423
# unique          38
# top     01/09/2024
# freq            46

# %%
import re

# %%
data = """

"""

# %%
aff_comp_protection = pd.read_csv('aff_compprotection', sep = '\t', header = None)
aff_health_care = pd.read_csv('aff_health_care', sep = '\t', header = None)
aff_ID_docs = pd.read_csv('aff_ID_docs', sep = '\t', header = None)
aff_incomplete_protection = pd.read_csv('aff_incomplete_2018', sep = '\t', header = None)
aff_other = pd.read_csv('aff_other', sep = '\t', header = None)

anti_adoption = pd.read_csv('anti_adoption', sep = '\t', header = None)


anti_FADA_and_religious_exemption=  pd.read_csv('anti_FADA_and_religious_exemption', sep = '\t', header = None)
anti_first_amend_def =  pd.read_csv('anti_first_amend_def', sep = '\t', header = None)

anti_health_care = pd.read_csv('anti_health_care', sep = '\t', header = None)

anti_marriage_rel_exemption =  pd.read_csv('anti_marriage_rel_exemption', sep = '\t', header = None)

anti_preempt_local_protection =  pd.read_csv('anti_preempt_local_protection', sep = '\t', header = None)

anti_religious_exemption_RFRA =  pd.read_csv('anti_religious_exemption_RFRA', sep = '\t', header = None)

anti_school_and_student_org =  pd.read_csv('anti_school_and_student_org', sep = '\t', header = None)

anti_single_sex_restrooms = pd.read_csv('anti_single_sex_restrooms', sep = '\t', header = None)

other_anti_lgbt = pd.read_csv('other_anti_lgbt', sep = '\t', header = None)

other_anti_trans =  pd.read_csv('other_anti_trans', sep = '\t', header = None)

other_rel_exemption = pd.read_csv('other_rel_exemption', sep = '\t', header = None)

# %%
def make_df(tdf, which_type):
    ind = 0
    state=[]
    number = []
    status = []
    for each in tdf[0]:
        if ind % 3 == 0:
            state.append(each)
        elif ind % 3 == 1:
            number.append(each)
        else:
            status.append(each)
        ind += 1
    
    new_df = pd.DataFrame()

    new_df['State'] = state
    new_df['number'] = number
    new_df['status'] = status

    
    dates = []
    statuses = []
    for status in new_df['status']:
        parts = status.split(': ')
        if len(parts) > 1:
            dates.append(parts[0])
            statuses.append(': '.join(parts[1:]))
        else:
            dates.append('')
            statuses.append(parts[0])

    new_df['Date'] = dates
    new_df['status'] = statuses
    new_df = new_df.assign(dtype = which_type)
    
    new_df = new_df.drop(0)

    return new_df

# %%
#make_df(aff_comp_protection, 'aff_comp_protection')

# %%
df_list = [aff_comp_protection, aff_health_care, aff_ID_docs, aff_incomplete_protection, aff_other, anti_adoption, 
            anti_FADA_and_religious_exemption, anti_first_amend_def, anti_health_care, anti_marriage_rel_exemption,
            anti_preempt_local_protection, anti_religious_exemption_RFRA, anti_school_and_student_org,
            anti_single_sex_restrooms, other_anti_lgbt, other_anti_trans, other_rel_exemption]

# %%
df_names = ['aff_comp_protection', 'aff_health_care', 'aff_ID_docs', 'aff_incomplete_protection', 'aff_other', 'anti_adoption', 
            'anti_FADA_and_religious_exemption', 'anti_first_amend_def', 'anti_health_care', 'anti_marriage_rel_exemption',
            'anti_preempt_local_protection', 'anti_religious_exemption_RFRA', 'anti_school_and_student_org',
            'anti_single_sex_restrooms', 'other_anti_lgbt', 'other_anti_trans', 'other_rel_exemption']

# %%
#make_df(aff_ID_docs, 'aff_ID_docs')

# %%
for each, name in zip(df_list, df_names):
    
    try:
        each = make_df(each, name)
        
    except:
        print(name)
        
#identifies which ones are messed up

# %%
dfs = {}

# Loop through each element in the list
for each, name in zip(df_list, df_names):
    # Generate DataFrame for the current element
    new_df = make_df(each, name)
    
    # Store the DataFrame in the dictionary with element as key
    dfs[name] = new_df

# %%
dfs['aff_comp_protection']
# Out:
#    State   number                                             status  \
# 1     AZ  HB 2462                                      Session ended
# 2     AZ  HB 2586                                      Session ended
# 3     FL   HB 347                                               Dead
# 4     FL    SB 66                                               Dead
# 5     GA   HB 987                                      Session ended
# 6     ID    H 408                                      Session ended
# 7     IN   SB 285                                      Session ended
# 8     MI  HB 4689      Introduced 5/31/17; electronically reproduced
# 9     MI   SB 424                          Referred to committee (S)
# 10    MO  HB 1360                                 Second reading (H)
# 11    MO  HB 2311                                 Second reading (H)
# 12    MO   SB 753          Second reading; referred to committee (S)
# 13    MS   HB 545                                               Dead
# 14    MS  SB 2933                                               Dead
# 15    NC    H 906                          Referred to committee (H)
# 16    NH  HB 1319                                 Signed by Governor
# 17    NY  SB 7010  Notice of committee consideration – requested (S)
# 18    PA  HB 1410  Resolution to discharge committee from further...
# 19    PA   SB 613            (Remarks see Senate Journal Page …) (S)
# 20    VA   HB 401                              Left in committee (H)
# 21    WI   AB 418  Failed to pass pursuant to Senate Joint Resolu...
# 22    WI   SB 328  Failed to pass pursuant to Senate Joint Resolu...
# 23    WV  HB 4319                                      Session ended
# 24    WV   SB 471                                      Session ended
# 25    AK    HB 82                          Referred to State Affairs
# 26    ID   S 1015                                          DEAD BILL
# 27    IN   SB 402                                          DEAD BILL
# 28    KY   HB 164                                          DEAD BILL
# 29    MO   SB 172                                          DEAD BILL
# 30    MS   HB 251                                          DEAD BILL
# 31    ND  HB 1441                                          DEAD BILL
# 32    ND  HB 2303                                          DEAD BILL
# 33    NY   AB 747                             Substituted by SB 1047
# 34    NY  SB 1047                                 Signed by Governor
# 35    NY  AB 1592                              Referred to Education
# 36    NY  SB 1857                              Referred to Education
# 37    SC   H 3239                 Referred to Committee on Judiciary
# 38    WI   SB 308                          Fiscal Estimate Received
# 39    WI   AB 319                          Fiscal Estimate Received
# 40    VA  HB 2421                                          DEAD BILL
#
#           Date                dtype
# 1    1/25/2018  aff_comp_protection
# 2     2/7/2018  aff_comp_protection
# 3    3/10/2018  aff_comp_protection
# 4    3/10/2018  aff_comp_protection
# 5    2/23/2018  aff_comp_protection
# 6    1/26/2018  aff_comp_protection
# 7     1/4/2018  aff_comp_protection
# 8     6/6/2017  aff_comp_protection
# 9    5/31/2017  aff_comp_protection
# 10    1/4/2018  aff_comp_protection
# 11   1/31/2018  aff_comp_protection
# 12   1/16/2018  aff_comp_protection
# 13   1/30/2018  aff_comp_protection
# 14   1/30/2018  aff_comp_protection
# 15   4/26/2017  aff_comp_protection
# 16   6/13/2018  aff_comp_protection
# 17   3/19/2018  aff_comp_protection
# 18  12/12/2017  aff_comp_protection
# 19   4/24/2018  aff_comp_protection
# 20   2/13/2018  aff_comp_protection
# 21   3/28/2018  aff_comp_protection
# 22   3/28/2018  aff_comp_protection
# 23   1/26/2018  aff_comp_protection
# 24    2/2/2018  aff_comp_protection
# 25    3/8/2019  aff_comp_protection
# 26   3/29/2019  aff_comp_protection
# 27   4/29/2019  aff_comp_protection
# 28   3/30/2019  aff_comp_protection
# 29   5/30/2019  aff_comp_protection
# 30    4/8/2019  aff_comp_protection
# 31   4/26/2019  aff_comp_protection
# 32   4/26/2019  aff_comp_protection
# 33   1/15/2019  aff_comp_protection
# 34   1/25/2019  aff_comp_protection
# 35   1/15/2019  aff_comp_protection
# 36   1/16/2019  aff_comp_protection
# 37    1/8/2019  aff_comp_protection
# 38   7/25/2019  aff_comp_protection
# 39   7/25/2019  aff_comp_protection
# 40   2/23/2019  aff_comp_protection

# %%
combined_df = pd.concat(dfs.values(), ignore_index=True)

# %%
combined_df['State'].unique()
# Out:
# array(['AZ', 'FL', 'GA', 'ID', 'IN', 'MI', 'MO', 'MS', 'NC', 'NH', 'NY',
#        'PA', 'VA', 'WI', 'WV', 'AK', 'KY', 'ND', 'SC', 'CO', 'CT', 'HI',
#        'MA', 'NJ ', 'NJ', 'NY ', 'LA', 'State', 'KS', 'IL', 'MD', 'MT',
#        'NE', 'NM', 'NV ', 'OH', 'TX', 'MI ', 'OK', 'AR', 'TN', 'TX ',
#        'NV', 'IA', 'MO ', 'SD', 'TN ', 'WA', 'WY', 'IN '], dtype=object)

# %%
combined_df['dtype'].unique()
# Out:
# array(['aff_comp_protection', 'aff_health_care', 'aff_ID_docs',
#        'aff_incomplete_protection', 'aff_other', 'anti_adoption',
#        'anti_FADA_and_religious_exemption', 'anti_first_amend_def',
#        'anti_health_care', 'anti_marriage_rel_exemption',
#        'anti_preempt_local_protection', 'anti_religious_exemption_RFRA',
#        'anti_school_and_student_org', 'anti_single_sex_restrooms',
#        'other_anti_lgbt', 'other_anti_trans', 'other_rel_exemption'],
#       dtype=object)

# %%
combined_df[combined_df['number'] == 'HB 1206']
#this is actually listed twice in the dataset, maybe it applies to both
# Out:
#     State   number         status       Date  \
# 146    CO  HB 1206  Session ended  3/27/2018
# 163    CO  HB 1206  Session ended  3/27/2018
#
#                                  dtype
# 146                      anti_adoption
# 163  anti_FADA_and_religious_exemption

# %%
combined_df = combined_df[combined_df['State'] != 'State']

# %%
combined_df.describe()

#this is the ones i had to manually ad from text files, the others are easier to upload
# Out:
#        State   number     status       Date                      dtype
# count    243      243        243        243                        243
# unique    49      232         80        109                         17
# top       TX  HB 1206  DEAD BILL  5/27/2019  aff_incomplete_protection
# freq      22        2         58         21                         82
